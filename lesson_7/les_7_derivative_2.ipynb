# %% [markdown]
# # Тема "Производная функции одной переменной".

# %% [markdown]
# __Задание №1.__ Найти длину 𝑥 и ширину 𝑦 прямоугольника при заданном периметре 𝑃=144 cм, при которых данный прямоугольник имеет наибольшую площадь 𝑆.
#
# Формула площади прямоугольника: $\normalsize S(x,y)=xy$, которая зависит от двух переменных(сторон).
#
# Так как нам известен периметр: $\normalsize P=2(x+y)$, то мы можем выразить одну сторону через другую:
#
# $\normalsize 144=2(x+y)\,\,\,\Rightarrow\,\,\,y=72-x$
#
# Подставив в формулу для нахождения площади прямоугольника, получим формулу площади, зависящей только от одной стороны:
#
# $\normalsize S(x)=x(72-x)=72x-x^2$
#
# Найдем производную:
#
# $\normalsize S'(x)=72-2x$
#
# Функция $\normalsize S(x)$ имеет значения на всей области определения, поэтому для нахождения критической точки приравняем производную к 0, и так как x входит в производную в 1-ой степени, то этой точке производная будет менять знак и точка будет являться экстремумом:
#
# $\normalsize 72-2x=0$
# $\normalsize x=36$
# $\normalsize S'(40)=-8$
#
# Справа от найденного экстремума производная отрицательна, значит слева от него она положительна. Следовательно мы нашли максимум, и в данном случае это глобальный максимум.
#
# $\normalsize x_{max}=36\,\,\,\,\,\,y_{max}=72-x_{max}=36\,\,\,\,\,\,S_{max}=x_{max}\cdot y_{max}=1296$
#
# __Ответ:__ $\normalsize x_{max}=36\,\,\,\,\,\,y_{max}=36$

# %% [markdown]
# __Задание №2.__ Найти экстремумы функций (если они есть).
#
# - $\large y=|2x|$
#
#   Формула нахождения производной модуля: $\displaystyle\normalsize\Big(\big|f(x)\big|\Big)' = \frac{f'(x)\cdot f(x)}{\big|f(x)\big|}$.
#
#   $\displaystyle\large y'=\frac{4x}{|2x|}$
#
#   Единственная критическая точка функции, это $x=0$, где производной не существует.
#   Значения справа и слева от найденной точки: $y'(-1)=-2,\,\,\,y'(1)=2$.
#   Производная меняет свой знак с "-" на "+" в найденной критической точке, следовательно это __минимум__ в точке $x=0,\,\,\,y(0)=0$.
#
#   __Ответ:__ минимум в точке $(0,0)$
# ___
# - $\large y=x^3$
#
#   $\large y'=3x^2$
#
#   Производная имеет значения на всей области определения. Приравняем производную к нулю:
#
#   $\large 3x^2=0$
#
#   $\large x_{1,2}=0$
#
#   Найдена одна критическая точка. Так как она входит в производную во 2-ой степени, она не является экстремумом.
#
#   __Ответ:__ функция не имеет экстремумов.
# ___
# - $\large y=e^{3x}$
#
#   $\large y'=3e^{3x}$
#
#   Так как область значений производной: $(0,+\infty)$, то есть производная всегда положительна, следовательно функция не имеет экстремумов.
#
#   __Ответ:__ функция не имеет экстремумов.
# ___
# - $\large y=x^3-5x$
#
#   $\large y'=3x^2-5$
#
#   Производная имеет значения на всей области определения. Приравняем производную к нулю:
#
#   $\large 3x^2-5=0$
#
#   $\large \bigg(x+\sqrt{\frac{5}{3}}\bigg)\bigg(x-\sqrt{\frac{5}{3}}\bigg)=0$
#
#   $\large x_1=-\sqrt{\frac{5}{3}},\,\,\,x_2=\sqrt{\frac{5}{3}}$
#
#   $\large y'(0)=-5$
#
#   Найдена две критических точки. Так как они обе входят в производную в 1-ой степени, они являются экстремумами. Между ними значение производной отрицательно, значит $x_1=-\sqrt{\frac{5}{3}}$ является локальным максимумом, $x_2=\sqrt{\frac{5}{3}}$ является локальным минимумом.
#   $y(x_1)=\frac{10}{3}\sqrt{\frac{5}{3}},\,\,\,\,y(x_2)=-\frac{10}{3}\sqrt{\frac{5}{3}}$
#
#   __Ответ:__
#   локальный максимум в точке $\bigg(-\sqrt{\frac{5}{3}};\,\frac{10}{3}\sqrt{\frac{5}{3}}\bigg)$,
#   локальный минимум в точке $\bigg(\sqrt{\frac{5}{3}};\,-\frac{10}{3}\sqrt{\frac{5}{3}}\bigg)$
